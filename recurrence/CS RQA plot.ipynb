# %% [markdown]
# ## Complex Systems RQA

# %%
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# get the aRQA REC% values 

# Pros GSR 
gsr_pro00 = 0.29
gsr_pro11 = 6.85
gsr_pro22 = 1.91
gsr_pro33 = 2.50
gsr_pro44 = 4.06

# Pros HRV 
hrv_pro00 = 2.25
hrv_pro11 = 2.71
hrv_pro22 = 2.63
hrv_pro33 = 2.33
hrv_pro44 = 2.04

# Amateurs GSR 
gsr_am00  = 3.46
gsr_am11  = 0.65
gsr_am22  = 1.75
gsr_am33  = 2.13
gsr_am44  = 2.03

# Amateurs HRV
hrv_am00  = 2.57
hrv_am11  = 2
hrv_am22  = 3.54
hrv_am33  = 2.76
hrv_am44  = 3.47

# %%
# get the CRQA Rec% values 

# Amateurs GSR 
gsr_am01 = 1.29   
gsr_am02 = 1.25   
gsr_am03 = 0
gsr_am04 = 0
gsr_am12 = 0.17  
gsr_am13 = 0.28  
gsr_am14 = 0
gsr_am23 = 0
gsr_am24 = 0
gsr_am34 = 0

# Amateurs HRV
hrv_am01 = 1.29  
hrv_am02 = 1.81  
hrv_am03 = 2.62  
hrv_am04 = 1.47  
hrv_am12 = 0.89  
hrv_am13 = 1.66  
hrv_am14 = 2.62  
hrv_am23 = 2.03  
hrv_am24 = 0.71    
hrv_am34 = 0.83  

# Pros GSR 
gsr_pro01 = 0
gsr_pro02 = 0
gsr_pro03 = 0
gsr_pro04 = 0
gsr_pro12 = 0
gsr_pro13 = 2.74   
gsr_pro14 = 0.62   
gsr_pro23 = 0
gsr_pro24 = 0
gsr_pro34 = 0.09  

# Pros HRV 
hrv_pro01 = 1.24
hrv_pro02 = 1.45  
hrv_pro03 = 2.29  
hrv_pro04 = 1.62  
hrv_pro12 = 1.43  
hrv_pro13 = 1.60
hrv_pro14 = 0.71     
hrv_pro23 = 1.81  
hrv_pro24 = 1.16  
hrv_pro34 = 0.42

# %% [markdown]
# ### RR matrix GSR Pro

# %%
gsr_pro0 = [gsr_pro00, gsr_pro01, gsr_pro02, gsr_pro03, gsr_pro04]
gsr_pro1 = [gsr_pro01, gsr_pro11, gsr_pro12, gsr_pro13, gsr_pro14]
gsr_pro2 = [gsr_pro02, gsr_pro12, gsr_pro22, gsr_pro23, gsr_pro24]
gsr_pro3 = [gsr_pro03, gsr_pro13, gsr_pro23, gsr_pro33, gsr_pro34]
gsr_pro4 = [gsr_pro04, gsr_pro14, gsr_pro24, gsr_pro34, gsr_pro44]

matrix_gsr_pro = [gsr_pro0, gsr_pro1, gsr_pro2, gsr_pro3, gsr_pro4]

# %%
labels = [f'player_{i}' for i in range(5)]
plt.figure(figsize=(10, 8))
sns.set_theme(font_scale=1.5)
sns.heatmap(matrix_gsr_pro, annot=True, cmap='viridis', fmt=".2f", linewidths=.5, cbar_kws={'label': 'Recurrence Rates GSR Pro'}, xticklabels=labels, yticklabels=labels)
plt.savefig('Recurrence_Rates_GSR_Pro.png')
plt.show()

# %% [markdown]
# ### RR matrix HRV Pro

# %%
hrv_pro0 = [hrv_pro00, hrv_pro01, hrv_pro02, hrv_pro03, hrv_pro04]
hrv_pro1 = [hrv_pro01, hrv_pro11, hrv_pro12, hrv_pro13, hrv_pro14]
hrv_pro2 = [hrv_pro02, hrv_pro12, hrv_pro22, hrv_pro23, hrv_pro24]
hrv_pro3 = [hrv_pro03, hrv_pro13, hrv_pro23, hrv_pro33, hrv_pro34]
hrv_pro4 = [hrv_pro04, hrv_pro14, hrv_pro24, hrv_pro34, hrv_pro44]

matrix_hrv_pro = [hrv_pro0, hrv_pro1, hrv_pro2, hrv_pro3, hrv_pro4]

# %%
labels = [f'player_{i}' for i in range(5)]
plt.figure(figsize=(10, 8))
sns.set_theme(font_scale=1.5)
sns.heatmap(matrix_hrv_pro, annot=True, cmap='viridis', fmt=".2f", linewidths=.5, cbar_kws={'label': 'Recurrence Rates HRV Pro'}, xticklabels=labels, yticklabels=labels)
plt.savefig('Recurrence_Rates_HRV_Pro.png')
plt.show()

# %% [markdown]
# ### RR matrix GSR Amateurs

# %%
gsr_am0 = [gsr_am00, gsr_am01, gsr_am02, gsr_am03, gsr_am04]
gsr_am1 = [gsr_am01, gsr_am11, gsr_am12, gsr_am13, gsr_am14]
gsr_am2 = [gsr_am02, gsr_am12, gsr_am22, gsr_am23, gsr_am24]
gsr_am3 = [gsr_am03, gsr_am13, gsr_am23, gsr_am33, gsr_am34]
gsr_am4 = [gsr_am04, gsr_am14, gsr_am24, gsr_am34, gsr_am44]

matrix_gsr_am = [gsr_am0, gsr_am1, gsr_am2, gsr_am3, gsr_am4]

# %%
labels = [f'player_{i}' for i in range(5)]
plt.figure(figsize=(10, 8))
sns.set_theme(font_scale=1.5)
sns.heatmap(matrix_gsr_am, annot=True, cmap='viridis', fmt=".2f", linewidths=.5, cbar_kws={'label': 'Recurrence Rates GSR Amateurs'}, xticklabels=labels, yticklabels=labels)
plt.savefig('Recurrence_Rates_GSR_Am.png')
plt.show()

# %% [markdown]
# ### RR matrix HRV Amateurs

# %%
hrv_am0 = [hrv_am00, hrv_am01, hrv_am02, hrv_am03, hrv_am04]
hrv_am1 = [hrv_am01, hrv_am11, hrv_am12, hrv_am13, hrv_am14]
hrv_am2 = [hrv_am02, hrv_am12, hrv_am22, hrv_am23, hrv_am24]
hrv_am3 = [hrv_am03, hrv_am13, hrv_am23, hrv_am33, hrv_am34]
hrv_am4 = [hrv_am04, hrv_am14, hrv_am24, hrv_am34, hrv_am44]

matrix_hrv_am = [hrv_am0, hrv_am1, hrv_am2, hrv_am3, hrv_am4]

# %%
labels = [f'player_{i}' for i in range(5)]
plt.figure(figsize=(10, 8))
sns.set_theme(font_scale=1.5)
sns.heatmap(matrix_hrv_am, annot=True, cmap='viridis', fmt=".2f", linewidths=.5, cbar_kws={'label': 'Recurrence Rates HRV Amateurs'}, xticklabels=labels, yticklabels=labels)
plt.savefig('Recurrence_Rates_HRV_Am.png')
plt.show()
